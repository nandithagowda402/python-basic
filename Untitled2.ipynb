# %% [markdown]
# <a href="https://colab.research.google.com/github/nandithagowda402/python-basic/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age= int(input("Enter your age:"))

if age>=18:
   print("you are eligible for voting")

else:
   print("you are not eligible for voting")
# Out:
# Enter your age:18
# you are eligible for voting

# %%
percentage = float(input("Enter student percentage: "))

if percentage < 50:
    grace_marks = 10
    final_percentage = percentage + grace_marks
    print("Grace marks included")
    print("Final Percentage:", final_percentage)
else:
    print("Grace marks not included")
    print("Percentage:", percentage)
# Out:
# Enter student percentage: 45
# Grace marks included
# Final Percentage: 55.0

# %%
Marks= int(input("Enter your Marks:"))

if Marks>=50:
   print("you passed 12th")

else:
   print("come again next year")
# Out:
# Enter your Marks:75
# you passed 12th
